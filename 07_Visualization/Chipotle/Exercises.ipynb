# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
try:
    chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
except:
    pass
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
chipo.groupby('item_name')['quantity'].count().sort_values()[::-1].head(5).plot(kind='bar');

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
chipo['order_price'] = chipo['quantity']*chipo['item_price']
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %%
chipo.groupby('item_name').agg({'quantity': 'sum',
                                'item_price': lambda x: x.mean(),
                                'order_price': 'sum'})
# Out:
#                                        quantity  item_price  order_price
# item_name
# 6 Pack Soft Drink                            55    6.610185       369.93
# Barbacoa Bowl                                66   10.187273       672.36
# Barbacoa Burrito                             91    9.832418       894.75
# Barbacoa Crispy Tacos                        12   10.928182       138.71
# Barbacoa Salad Bowl                          10   10.640000       106.40
# Barbacoa Soft Tacos                          25   10.018400       250.46
# Bottled Water                               211    1.867654       649.18
# Bowl                                          4   14.800000        74.00
# Burrito                                       6    7.400000        44.40
# Canned Soda                                 126    1.320577       191.84
# Canned Soft Drink                           351    1.457641       603.75
# Carnitas Bowl                                71   10.833971       830.71
# ...

# %%
plt.figure(figsize=(8,8))
chipo.groupby('item_name').agg({'quantity': 'sum',
                                'item_price': lambda x: 4*x.mean(),
                                'order_price': 'sum'}).plot(x='quantity',
                                                            y='order_price',
                                                            s='item_price',
                                                            c='red',
                                                            ec='k',
                                                            kind='scatter',
                                                            alpha=0.8);
plt.show();

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.
