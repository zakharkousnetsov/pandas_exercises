# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd

# visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns


# print the graphs in the notebook
% matplotlib inline

# set seaborn style to white
sns.set_style("white")
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv')
tips.sample()
# Out:
#     Unnamed: 0  total_bill   tip   sex smoker  day    time  size
# 53          53        9.94  1.56  Male     No  Sun  Dinner     2

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips = tips.iloc[:, 1:]
tips.sample()
# Out:
#      total_bill  tip     sex smoker  day    time  size
# 100       11.35  2.5  Female    Yes  Fri  Dinner     2

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
tips['total_bill'].hist(bins=20, grid=False);

# %%
sns.set_style("whitegrid", {'axes.grid' : False})
sns.displot(data=tips, x='total_bill', bins=20, fill=False);

# %%
sns.displot(data=tips, x='total_bill', y='tip', kind='kde', rug=True);

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
tips.plot(x='total_bill', y='tip', kind='scatter');

# %%
tips.plot.scatter(x='total_bill', y='tip', ec='w', s=35);

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip');
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
g = sns.jointplot(data=tips, x='total_bill', y='tip', hue='sex');
# g.plot_marginals(sns.rugplot, color="r", height=-.15, clip_on=False)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(data=tips);

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.stripplot(y="day",
              x="total_bill",
              hue='day',
              data=tips,
              orient='h',
              edgecolor='k',
              linewidth=0.5,
              alpha=0.9);

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(data=tips, x='tip', y='day', hue='sex');
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=tips, x='day', hue='time', y='total_bill', fliersize=2);

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
fig, ax = plt.subplots(1, 2)
sns.histplot(data=tips[tips['time']=='Dinner'], x='tip', ax=ax[0])
sns.histplot(data=tips[tips['time']=='Lunch'], x='tip', ax=ax[1]);
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g = sns.FacetGrid(data=tips, col='sex', hue='smoker')
g.map(sns.scatterplot, 'total_bill', 'tip');

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
